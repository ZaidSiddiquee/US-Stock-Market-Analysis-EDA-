# %% [markdown]
# Data set link: https://www.kaggle.com/datasets/saketk511/2019-2024-us-stock-market-data

# %% [markdown]
# # **Dataset Variable Information:¶**
# Date: The date of the recorded data, formatted as DD-MM-YYYY.
#
# Natural_Gas_Price: Price of natural gas in USD per million British thermal
# units (MMBtu).
#
# Natural_Gas_Vol.: Trading volume of natural gas.
#
# Crude_oil_Price: Price of crude oil in USD per barrel.
#
# Crude_oil_Vol.: Trading volume of crude oil.
#
# Copper_Price: Price of copper in USD per pound.
#
# Copper_Vol.: Trading volume of copper.
#
# Bitcoin_Price: Price of Bitcoin in USD.
#
# Bitcoin_Vol.: Trading volume of Bitcoin.
#
# Platinum_Price: Price of platinum in USD per troy ounce.
#
# Platinum_Vol.: Trading volume of platinum.
#
# Ethereum_Price: Price of Ethereum in USD.
#
# Ethereum_Vol.: Trading volume of Ethereum.
#
# S&P_500_Price: Price index of the S&P 500.
#
# Nasdaq_100_Price: Price index of the Nasdaq 100.
#
# Nasdaq_100_Vol.: Trading volume for the Nasdaq 100 index.
#
# Apple_Price: Stock price of Apple Inc. in USD.
#
# Apple_Vol.: Trading volume of Apple Inc. stock.
#
# Tesla_Price: Stock price of Tesla Inc. in USD.
#
# Tesla_Vol.: Trading volume of Tesla Inc. stock.
#
# Microsoft_Price: Stock price of Microsoft Corporation in USD.
#
# Microsoft_Vol.: Trading volume of Microsoft Corporation stock.
#
# Silver_Price: Price of silver in USD per troy ounce.
#
# Silver_Vol.: Trading volume of silver.
#
# Google_Price: Stock price of Alphabet Inc. (Google) in USD.
#
# Google_Vol.: Trading volume of Alphabet Inc. stock.
#
# Nvidia_Price: Stock price of Nvidia Corporation in USD.
#
# Nvidia_Vol.: Trading volume of Nvidia Corporation stock.
#
# Berkshire_Price: Stock price of Berkshire Hathaway Inc. in USD.
#
# Berkshire_Vol.: Trading volume of Berkshire Hathaway Inc. stock.
#
# Netflix_Price: Stock price of Netflix Inc. in USD.
#
# Netflix_Vol.: Trading volume of Netflix Inc. stock.
#
# Amazon_Price: Stock price of Amazon.com Inc. in USD.
#
# Amazon_Vol.: Trading volume of Amazon.com Inc. stock.
#
# Meta_Price: Stock price of Meta Platforms, Inc. (formerly Facebook) in USD.
#
# Meta_Vol.: Trading volume of Meta Platforms, Inc. stock.
#
# Gold_Price: Price of gold in USD per troy ounce.
#
# Gold_Vol.: Trading volume of gold.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Stock Market Dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date  Natural_Gas_Price  Natural_Gas_Vol.  \
# 0           0  02-02-2024              2.079               NaN
# 1           1  01-02-2024              2.050          161340.0
# 2           2  31-01-2024              2.100          142860.0
# 3           3  30-01-2024              2.077          139750.0
# 4           4  29-01-2024              2.490            3590.0
#
#    Crude_oil_Price  Crude_oil_Vol.  Copper_Price  Copper_Vol. Bitcoin_Price  \
# 0            72.28             NaN        3.8215          NaN     43,194.70
# 1            73.82        577940.0        3.8535          NaN     43,081.40
# 2            75.85        344490.0        3.9060          NaN     42,580.50
# 3            77.82        347240.0        3.9110          NaN     42,946.20
# 4            76.78        331930.0        3.8790          NaN     43,299.80
#
#    Bitcoin_Vol.  ... Berkshire_Price  Berkshire_Vol. Netflix_Price  \
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0        Date  Natural_Gas_Price  Natural_Gas_Vol.  \
# 1238        1238  08-02-2019              2.583          147880.0
# 1239        1239  07-02-2019              2.551          211790.0
# 1240        1240  06-02-2019              2.662           98330.0
# 1241        1241  05-02-2019              2.662           82250.0
# 1242        1242  04-02-2019              2.660          116490.0
#
#       Crude_oil_Price  Crude_oil_Vol.  Copper_Price  Copper_Vol.  \
# 1238            52.72        621000.0        2.8140        270.0
# 1239            52.64        749010.0        2.8320        320.0
# 1240            54.01        606720.0        2.8400        100.0
# 1241            53.66        609760.0        2.8205         90.0
# 1242            54.56        622470.0        2.7975        490.0
#
#      Bitcoin_Price  Bitcoin_Vol.  ... Berkshire_Price  Berkshire_Vol.  \
# 1238      3,661.70      699230.0  ...        3,00,771           240.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Natural_Gas_Price', 'Natural_Gas_Vol.',
#        'Crude_oil_Price', 'Crude_oil_Vol.', 'Copper_Price', 'Copper_Vol.',
#        'Bitcoin_Price', 'Bitcoin_Vol.', 'Platinum_Price', 'Platinum_Vol.',
#        'Ethereum_Price', 'Ethereum_Vol.', 'S&P_500_Price', 'Nasdaq_100_Price',
#        'Nasdaq_100_Vol.', 'Apple_Price', 'Apple_Vol.', 'Tesla_Price',
#        'Tesla_Vol.', 'Microsoft_Price', 'Microsoft_Vol.', 'Silver_Price',
#        'Silver_Vol.', 'Google_Price', 'Google_Vol.', 'Nvidia_Price',
#        'Nvidia_Vol.', 'Berkshire_Price', 'Berkshire_Vol.', 'Netflix_Price',
#        'Netflix_Vol.', 'Amazon_Price', 'Amazon_Vol.', 'Meta_Price',
#        'Meta_Vol.', 'Gold_Price', 'Gold_Vol.'],
#       dtype='object')

# %%
df.shape
# Out:
# (1243, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1243 entries, 0 to 1242
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1243 non-null   int64
#  1   Date               1243 non-null   object
#  2   Natural_Gas_Price  1243 non-null   float64
#  3   Natural_Gas_Vol.   1239 non-null   float64
#  4   Crude_oil_Price    1243 non-null   float64
#  5   Crude_oil_Vol.     1220 non-null   float64
#  6   Copper_Price       1243 non-null   float64
#  7   Copper_Vol.        1206 non-null   float64
#  8   Bitcoin_Price      1243 non-null   object
#  9   Bitcoin_Vol.       1243 non-null   float64
#  10  Platinum_Price     1243 non-null   object
#  11  Platinum_Vol.      636 non-null    float64
#  12  Ethereum_Price     1243 non-null   object
#  13  Ethereum_Vol.      1243 non-null   float64
#  14  S&P_500_Price      1243 non-null   object
# ...

# %%
df = df.drop(["Unnamed: 0"], axis = 1)

# %% [markdown]
# Removing commas from numeric values

# %%
for col in df.columns[1:]:
  df[col] = df[col].replace(",","",regex = True).astype("float64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1243 entries, 0 to 1242
# Data columns (total 38 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1243 non-null   object
#  1   Natural_Gas_Price  1243 non-null   float64
#  2   Natural_Gas_Vol.   1239 non-null   float64
#  3   Crude_oil_Price    1243 non-null   float64
#  4   Crude_oil_Vol.     1220 non-null   float64
#  5   Copper_Price       1243 non-null   float64
#  6   Copper_Vol.        1206 non-null   float64
#  7   Bitcoin_Price      1243 non-null   float64
#  8   Bitcoin_Vol.       1243 non-null   float64
#  9   Platinum_Price     1243 non-null   float64
#  10  Platinum_Vol.      636 non-null    float64
#  11  Ethereum_Price     1243 non-null   float64
#  12  Ethereum_Vol.      1243 non-null   float64
#  13  S&P_500_Price      1243 non-null   float64
#  14  Nasdaq_100_Price   1243 non-null   float64
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"], format='%d-%m-%Y', dayfirst=True)

# %%
df.isna().sum()
# Out:
# Date                   0
# Natural_Gas_Price      0
# Natural_Gas_Vol.       4
# Crude_oil_Price        0
# Crude_oil_Vol.        23
# Copper_Price           0
# Copper_Vol.           37
# Bitcoin_Price          0
# Bitcoin_Vol.           0
# Platinum_Price         0
# Platinum_Vol.        607
# Ethereum_Price         0
# Ethereum_Vol.          0
# S&P_500_Price          0
# Nasdaq_100_Price       0
# Nasdaq_100_Vol.        1
# Apple_Price            0
# Apple_Vol.             0
# Tesla_Price            0
# Tesla_Vol.             0
# Microsoft_Price        0
# Microsoft_Vol.         0
# Silver_Price           0
# Silver_Vol.           47
# Google_Price           0
# Google_Vol.            0
# Nvidia_Price           0
# Nvidia_Vol.            0
# Berkshire_Price        0
# Berkshire_Vol.         0
# Netflix_Price          0
# Netflix_Vol.           0
# Amazon_Price           0
# Amazon_Vol.            0
# Meta_Price             0
# Meta_Vol.              0
# Gold_Price             0
# ...

# %%
df.describe()
# Out:
#                                 Date  Natural_Gas_Price  Natural_Gas_Vol.  \
# count                           1243        1243.000000       1239.000000
# mean   2021-08-02 10:03:34.320193024           3.494714     131624.116223
# min              2019-02-04 00:00:00           1.482000       1200.000000
# 25%              2020-04-28 12:00:00           2.347500      91900.000000
# 50%              2021-08-03 00:00:00           2.702000     127370.000000
# 75%              2022-11-05 12:00:00           4.055500     169460.000000
# max              2024-02-02 00:00:00           9.647000     381970.000000
# std                              NaN           1.822540      64385.141749
#
#        Crude_oil_Price  Crude_oil_Vol.  Copper_Price    Copper_Vol.  \
# count      1243.000000    1.220000e+03   1243.000000    1206.000000
# mean         67.577064    3.989038e+05      3.541957   35406.616915
# min         -37.630000    1.702000e+04      2.100500      10.000000
# ...

# %%
df[df["Crude_oil_Price"] < 0]
# Out:
#           Date  Natural_Gas_Price  Natural_Gas_Vol.  Crude_oil_Price  \
# 938 2020-04-20              1.924          229820.0           -37.63
#
#      Crude_oil_Vol.  Copper_Price  Copper_Vol.  Bitcoin_Price  Bitcoin_Vol.  \
# 938        247950.0         2.328       1260.0         6833.5     1260000.0
#
#      Platinum_Price  ...  Berkshire_Price  Berkshire_Vol.  Netflix_Price  \
# 938           788.6  ...         282800.0           720.0         437.49
#
#      Netflix_Vol.  Amazon_Price  Amazon_Vol.  Meta_Price   Meta_Vol.  \
# 938    12660000.0        119.68  115410000.0      178.24  16110000.0
#
#      Gold_Price  Gold_Vol.
# 938      1711.2   186910.0
#
# [1 rows x 38 columns]

# %%
df.bfill().isna().sum()
# Out:
# Date                   0
# Natural_Gas_Price      0
# Natural_Gas_Vol.       0
# Crude_oil_Price        0
# Crude_oil_Vol.         0
# Copper_Price           0
# Copper_Vol.            0
# Bitcoin_Price          0
# Bitcoin_Vol.           0
# Platinum_Price         0
# Platinum_Vol.        375
# Ethereum_Price         0
# Ethereum_Vol.          0
# S&P_500_Price          0
# Nasdaq_100_Price       0
# Nasdaq_100_Vol.        0
# Apple_Price            0
# Apple_Vol.             0
# Tesla_Price            0
# Tesla_Vol.             0
# Microsoft_Price        0
# Microsoft_Vol.         0
# Silver_Price           0
# Silver_Vol.            0
# Google_Price           0
# Google_Vol.            0
# Nvidia_Price           0
# Nvidia_Vol.            0
# Berkshire_Price        0
# Berkshire_Vol.         0
# Netflix_Price          0
# Netflix_Vol.           0
# Amazon_Price           0
# Amazon_Vol.            0
# Meta_Price             0
# Meta_Vol.              0
# Gold_Price             0
# ...

# %%
df.ffill().isna().sum()
# Out:
# Date                  0
# Natural_Gas_Price     0
# Natural_Gas_Vol.      1
# Crude_oil_Price       0
# Crude_oil_Vol.        1
# Copper_Price          0
# Copper_Vol.          26
# Bitcoin_Price         0
# Bitcoin_Vol.          0
# Platinum_Price        0
# Platinum_Vol.        23
# Ethereum_Price        0
# Ethereum_Vol.         0
# S&P_500_Price         0
# Nasdaq_100_Price      0
# Nasdaq_100_Vol.       0
# Apple_Price           0
# Apple_Vol.            0
# Tesla_Price           0
# Tesla_Vol.            0
# Microsoft_Price       0
# Microsoft_Vol.        0
# Silver_Price          0
# Silver_Vol.           1
# Google_Price          0
# Google_Vol.           0
# Nvidia_Price          0
# Nvidia_Vol.           0
# Berkshire_Price       0
# Berkshire_Vol.        0
# Netflix_Price         0
# Netflix_Vol.          0
# Amazon_Price          0
# Amazon_Vol.           0
# Meta_Price            0
# Meta_Vol.             0
# Gold_Price            0
# Gold_Vol.             1
# ...

# %%
df.bfill(inplace = True)

# %% [markdown]
# Platinum volume has many missing values, so let's just drop platinum cols now.

# %%
del df["Platinum_Price"]

# %%
del df["Platinum_Vol."]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1243 entries, 0 to 1242
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1243 non-null   datetime64[ns]
#  1   Natural_Gas_Price  1243 non-null   float64
#  2   Natural_Gas_Vol.   1243 non-null   float64
#  3   Crude_oil_Price    1243 non-null   float64
#  4   Crude_oil_Vol.     1243 non-null   float64
#  5   Copper_Price       1243 non-null   float64
#  6   Copper_Vol.        1243 non-null   float64
#  7   Bitcoin_Price      1243 non-null   float64
#  8   Bitcoin_Vol.       1243 non-null   float64
#  9   Ethereum_Price     1243 non-null   float64
#  10  Ethereum_Vol.      1243 non-null   float64
#  11  S&P_500_Price      1243 non-null   float64
#  12  Nasdaq_100_Price   1243 non-null   float64
#  13  Nasdaq_100_Vol.    1243 non-null   float64
#  14  Apple_Price        1243 non-null   float64
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Natural_Gas_Price, Natural_Gas_Vol., Crude_oil_Price, Crude_oil_Vol., Copper_Price, Copper_Vol., Bitcoin_Price, Bitcoin_Vol., Ethereum_Price, Ethereum_Vol., S&P_500_Price, Nasdaq_100_Price, Nasdaq_100_Vol., Apple_Price, Apple_Vol., Tesla_Price, Tesla_Vol., Microsoft_Price, Microsoft_Vol., Silver_Price, Silver_Vol., Google_Price, Google_Vol., Nvidia_Price, Nvidia_Vol., Berkshire_Price, Berkshire_Vol., Netflix_Price, Netflix_Vol., Amazon_Price, Amazon_Vol., Meta_Price, Meta_Vol., Gold_Price, Gold_Vol.]
# Index: []
#
# [0 rows x 36 columns]

# %% [markdown]
# # **Categories and Columns**
# **Commodities:**
# Prices: Natural_Gas_Price, Crude_oil_Price
#
# Volumes: Natural_Gas_Vol., Crude_oil_Vol
#
# **Metals:**
# Prices: Gold_Price, Silver_Price, Copper_Price
#
# Volumes: Gold_Vol., Silver_Vol, Copper_Vol
#
# **Cryptocurrencies:**
# Prices: Bitcoin_Price, Ethereum_Price
#
# Volumes: Bitcoin_Vol., Ethereum_Vol.
#
#
# **Indices:**
# Prices: S&P_500_Price, Nasdaq_100_Price
#
# Volumes: Nasdaq_100_Vol.
#
#
# **Tech Companies:**
# Prices: Apple_Price, Tesla_Price, Microsoft_Price, Google_Price, Nvidia_Price, Netflix_Price, Amazon_Price, Meta_Price, Berkshire_Price
#
# Volumes: Apple_Vol., Tesla_Vol., Microsoft_Vol., Google_Vol., Nvidia_Vol., Netflix_Vol., Amazon_Vol., Meta_Vol., Berkshire_Vol.

# %% [markdown]
# # **Commodities:**

# %%
Commodities = ["Natural_Gas_Price", "Natural_Gas_Vol.", "Crude_oil_Price", "Crude_oil_Vol." ]

# %%
# creating a new dataframe for commodities data
Commodities_data = df[["Date"] + Commodities]
Commodities_data
# Out:
#            Date  Natural_Gas_Price  Natural_Gas_Vol.  Crude_oil_Price  \
# 0    2024-02-02              2.079          161340.0            72.28
# 1    2024-02-01              2.050          161340.0            73.82
# 2    2024-01-31              2.100          142860.0            75.85
# 3    2024-01-30              2.077          139750.0            77.82
# 4    2024-01-29              2.490            3590.0            76.78
# ...         ...                ...               ...              ...
# 1238 2019-02-08              2.583          147880.0            52.72
# 1239 2019-02-07              2.551          211790.0            52.64
# 1240 2019-02-06              2.662           98330.0            54.01
# 1241 2019-02-05              2.662           82250.0            53.66
# 1242 2019-02-04              2.660          116490.0            54.56
#
#       Crude_oil_Vol.
# 0           577940.0
# 1           577940.0
# 2           344490.0
# 3           347240.0
# ...

# %%
Commodities_data.set_index("Date", inplace = True)

# %%
Commodities_data
# Out:
#             Natural_Gas_Price  Natural_Gas_Vol.  Crude_oil_Price  \
# Date
# 2024-02-02              2.079          161340.0            72.28
# 2024-02-01              2.050          161340.0            73.82
# 2024-01-31              2.100          142860.0            75.85
# 2024-01-30              2.077          139750.0            77.82
# 2024-01-29              2.490            3590.0            76.78
# ...                       ...               ...              ...
# 2019-02-08              2.583          147880.0            52.72
# 2019-02-07              2.551          211790.0            52.64
# 2019-02-06              2.662           98330.0            54.01
# 2019-02-05              2.662           82250.0            53.66
# 2019-02-04              2.660          116490.0            54.56
#
#             Crude_oil_Vol.
# Date
# 2024-02-02        577940.0
# 2024-02-01        577940.0
# 2024-01-31        344490.0
# 2024-01-30        347240.0
# 2024-01-29        331930.0
# ...

# %%
Commodities_data.describe()
# Out:
#        Natural_Gas_Price  Natural_Gas_Vol.  Crude_oil_Price  Crude_oil_Vol.
# count        1243.000000       1243.000000      1243.000000    1.243000e+03
# mean            3.494714     131568.696702        67.577064    3.987463e+05
# std             1.822540      64338.050433        20.465500    2.142232e+05
# min             1.482000       1200.000000       -37.630000    1.702000e+04
# 25%             2.347500      91900.000000        55.095000    2.857900e+05
# 50%             2.702000     127370.000000        69.230000    3.683000e+05
# 75%             4.055500     169340.000000        80.455000    5.037300e+05
# max             9.647000     381970.000000       123.700000    1.770000e+06

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Commodities Price trends over time

# %%
plt.figure(figsize = (12,6))
for col in ["Natural_Gas_Price", "Crude_oil_Price"]:
  plt.plot(Commodities_data.index,Commodities_data[col], label=col)

plt.title("Commodities price trends over time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Comparing average trading volumes of commodities

# %%
Average_commodities_volums = Commodities_data[["Natural_Gas_Vol.", "Crude_oil_Vol."]].mean()
Average_commodities_volums
# Out:
# Natural_Gas_Vol.    131568.696702
# Crude_oil_Vol.      398746.331456
# dtype: float64

# %%
plt.figure(figsize = (8,5))
sns.barplot(x = Average_commodities_volums.index, y = Average_commodities_volums.values , palette = "viridis")
plt.title("Average Trading Volumns of Commodities")
plt.xlabel("Commodities")
plt.ylabel("Average_Volumne")
plt.show()
# Out:
# <ipython-input-29-d615168db0b7>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = Average_commodities_volums.index, y = Average_commodities_volums.values , palette = "viridis")

# %% [markdown]
# Crude Oil is traded a lot more in volume than Natural **Gas**

# %%
correlation_commodities_data = Commodities_data[["Natural_Gas_Price", "Natural_Gas_Vol.", "Crude_oil_Price", "Crude_oil_Vol."]]
correlation_commodities_data
# Out:
#             Natural_Gas_Price  Natural_Gas_Vol.  Crude_oil_Price  \
# Date
# 2024-02-02              2.079          161340.0            72.28
# 2024-02-01              2.050          161340.0            73.82
# 2024-01-31              2.100          142860.0            75.85
# 2024-01-30              2.077          139750.0            77.82
# 2024-01-29              2.490            3590.0            76.78
# ...                       ...               ...              ...
# 2019-02-08              2.583          147880.0            52.72
# 2019-02-07              2.551          211790.0            52.64
# 2019-02-06              2.662           98330.0            54.01
# 2019-02-05              2.662           82250.0            53.66
# 2019-02-04              2.660          116490.0            54.56
#
#             Crude_oil_Vol.
# Date
# 2024-02-02        577940.0
# 2024-02-01        577940.0
# 2024-01-31        344490.0
# 2024-01-30        347240.0
# 2024-01-29        331930.0
# ...

# %%
plt.figure(figsize = (10,6))
sns.heatmap(correlation_commodities_data.corr(), annot = True, cmap = "coolwarm", fmt = ".2f")
plt.title("Correlation between commodities Price and Volums")
plt.show()

# %% [markdown]
# Natural Gas and Crude Oil Price are highly correlated.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Natural Gas: Price vs Trading **Volume**

# %%
palette = { 2019: 'blue', 2020: 'orange', 2021: 'green', 2022: 'red', 2023: 'purple', 2024: 'brown'}

# %%
Commodities_data["Year"] = Commodities_data.index.year
# Out:
# <ipython-input-33-46a5140bca8f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Commodities_data["Year"] = Commodities_data.index.year

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(x = Commodities_data["Natural_Gas_Price"], y = Commodities_data["Natural_Gas_Vol."], color = "blue", hue = Commodities_data["Year"], palette = palette)

plt.title("Natural Gas: Price vs. trading Volume")
plt.xlabel("price")
plt.ylabel("Volume")
plt.grid()
plt.show()

# %% [markdown]
# We can see that for years 2021 and 2022, the Natural Gas price was a lot higher compared to other years, most probably due to COVID Pandemic.
#
# While in 2020, the prices were below $2.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Crude Oil: Price vs Trading volume

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(x = Commodities_data["Crude_oil_Price"],  y = Commodities_data["Crude_oil_Vol."], color = 'red', hue = Commodities_data["Year"], palette=palette)

plt.title("Crude Oil: Price vs. trading volume")
plt.xlabel("Price")
plt.ylabel("Volume")
plt.grid()
plt.show()

# %% [markdown]
# Crude Oil Prices were increased in 2022.
#
# Also, the volume was a lot higher in 2019 and 2020, compared to the years after that.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %%
Commodities_data.head()
# Out:
#             Natural_Gas_Price  Natural_Gas_Vol.  Crude_oil_Price  \
# Date
# 2024-02-02              2.079          161340.0            72.28
# 2024-02-01              2.050          161340.0            73.82
# 2024-01-31              2.100          142860.0            75.85
# 2024-01-30              2.077          139750.0            77.82
# 2024-01-29              2.490            3590.0            76.78
#
#             Crude_oil_Vol.  Year
# Date
# 2024-02-02        577940.0  2024
# 2024-02-01        577940.0  2024
# 2024-01-31        344490.0  2024
# 2024-01-30        347240.0  2024
# 2024-01-29        331930.0  2024

# %%
#This code is finding the row in the Commodities_data DataFrame where the "Crude_oil_Vol." value is the highest.
Commodities_data.loc[Commodities_data["Crude_oil_Vol."].idxmax()]
# Out:
# Natural_Gas_Price          1.778
# Natural_Gas_Vol.      291350.000
# Crude_oil_Price           31.130
# Crude_oil_Vol.       1770000.000
# Year                    2020.000
# Name: 2020-03-09 00:00:00, dtype: float64

# %% [markdown]
# On, March 9th 2020, the highest volume of Crude Oil was traded.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # Metals:**¶**

# %%
metals = ['Gold_Price', 'Gold_Vol.',
          'Silver_Price', 'Silver_Vol.',
          'Copper_Price', 'Copper_Vol.']

# %%
metals_data = df[["Date"]+metals]
metals_data.set_index("Date", inplace = True)

# %%
metals_data.describe()
# Out:
#         Gold_Price      Gold_Vol.  Silver_Price    Silver_Vol.  Copper_Price  \
# count  1243.000000    1243.000000   1243.000000    1243.000000   1243.000000
# mean   1759.246742  211210.925181     21.588977   66014.859212      3.541957
# std     203.258901  114932.469723      3.859288   38501.379968      0.702819
# min    1272.000000       0.000000     11.772000       0.000000      2.100500
# 25%    1669.600000  152215.000000     17.998500   46745.000000      2.858750
# 50%    1804.200000  197980.000000     22.758000   62060.000000      3.666000
# 75%    1912.800000  259220.000000     24.512000   78555.000000      4.137250
# max    2089.700000  813410.000000     29.418000  355280.000000      4.937500
#
#          Copper_Vol.
# count    1243.000000
# mean    35761.496380
# std     38003.810299
# min        10.000000
# 25%       385.000000
# 50%     24880.000000
# 75%     68210.000000
# max    176040.000000

# %%
metals_data.head()
# Out:
#             Gold_Price  Gold_Vol.  Silver_Price  Silver_Vol.  Copper_Price  \
# Date
# 2024-02-02      2053.7   260920.0        22.796      85160.0        3.8215
# 2024-02-01      2071.1   260920.0        23.236      85160.0        3.8535
# 2024-01-31      2067.4   238370.0        23.169      66910.0        3.9060
# 2024-01-30      2050.9   214590.0        23.225      53370.0        3.9110
# 2024-01-29      2034.9     1780.0        23.134        330.0        3.8790
#
#             Copper_Vol.
# Date
# 2024-02-02      38000.0
# 2024-02-01      38000.0
# 2024-01-31      38000.0
# 2024-01-30      38000.0
# 2024-01-29      38000.0

# %%
metals_data[metals_data["Gold_Vol."] == 0]
# Out:
#             Gold_Price  Gold_Vol.  Silver_Price  Silver_Vol.  Copper_Price  \
# Date
# 2023-05-25      1943.1        0.0        22.803        360.0        3.5825
# 2023-05-23      1972.4        0.0        23.509        380.0        3.6545
# 2023-05-15      2018.0        0.0        24.175        170.0        3.7510
# 2019-09-03      1552.8        0.0        19.186         60.0        2.5235
#
#             Copper_Vol.
# Date
# 2023-05-25        930.0
# 2023-05-23      69190.0
# 2023-05-15      59890.0
# 2019-09-03        770.0

# %%
metals_data[metals_data["Silver_Vol."] == 0]
# Out:
#             Gold_Price  Gold_Vol.  Silver_Price  Silver_Vol.  Copper_Price  \
# Date
# 2023-06-27      1915.1      230.0        22.939          0.0        3.7885
# 2023-06-22      1915.0      370.0        22.436          0.0        3.9005
# 2023-06-15      1961.8      820.0        23.891          0.0        3.9040
#
#             Copper_Vol.
# Date
# 2023-06-27      51670.0
# 2023-06-22      43050.0
# 2023-06-15      37030.0

# %% [markdown]
# Both Gold and Silver volumes were zero at some point.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Metals Price trends over time

# %%
plt.figure(figsize = (12,6))
for col in ["Gold_Price", "Silver_Price", "Copper_Price"]:
  plt.plot(metals_data.index, metals_data[col], label = [col])


plt.title("Metals price trends over time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Lets, divide the above plot into two subplots - gold and (silver, copper)

# %%
plt.figure(figsize = (12,6))
for col in ["Silver_Price", "Copper_Price"]:
  plt.plot(metals_data.index, metals_data[col], label = col)

plt.title("Metals price over trend")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# There was a big jump in price of Siler in mid 2020. Whereas, copper price incresed gradually and without any sudden rise in price.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %%
plt.figure(figsize = (12,6))
for col in ["Gold_Price"]:
  plt.plot(metals_data.index, metals_data[col], label = [col])

plt.title("Price of gold over time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Gold Prices flucuated a lot. Also, the price show a sudden and dramatic increase on two points -
#
# 1. around mid 2020,
#
# 2. near end of 2023.

# %% [markdown]
# Average volume traded for metals:

# %%
metals_data.head()
# Out:
#             Gold_Price  Gold_Vol.  Silver_Price  Silver_Vol.  Copper_Price  \
# Date
# 2024-02-02      2053.7   260920.0        22.796      85160.0        3.8215
# 2024-02-01      2071.1   260920.0        23.236      85160.0        3.8535
# 2024-01-31      2067.4   238370.0        23.169      66910.0        3.9060
# 2024-01-30      2050.9   214590.0        23.225      53370.0        3.9110
# 2024-01-29      2034.9     1780.0        23.134        330.0        3.8790
#
#             Copper_Vol.
# Date
# 2024-02-02      38000.0
# 2024-02-01      38000.0
# 2024-01-31      38000.0
# 2024-01-30      38000.0
# 2024-01-29      38000.0

# %%
avargae_metals_volume  = metals_data[["Gold_Vol.", "Silver_Vol.", "Copper_Vol."]].mean()

# %%
plt.figure(figsize = (8,5))
sns.barplot(x = avargae_metals_volume.index, y = avargae_metals_volume.values, palette = "viridis")

plt.title("Average trading volumne of metals")
plt.xlabel("Date")
plt.ylabel("Average_Volume")
plt.show()
# Out:
# <ipython-input-49-7b98280571a2>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = avargae_metals_volume.index, y = avargae_metals_volume.values, palette = "viridis")

# %%
correlation_metals_data = metals_data[["Gold_Price", "Gold_Vol.", "Silver_Price", "Silver_Vol.", "Copper_Price", "Copper_Vol."]]

# %%
plt.figure(figsize = (10,6))
sns.heatmap(correlation_metals_data.corr(), annot  = True, cmap = "coolwarm", fmt = ".2f")
plt.title("Correlation between metal price and Volume")
plt.show()

# %% [markdown]
# Gold, Silver and Copper all prices has a high positive correlation

# %%
metals_data["Year"] = metals_data.index.year
# Out:
# <ipython-input-52-f9db96ecd786>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metals_data["Year"] = metals_data.index.year

# %% [markdown]
# .

# %% [markdown]
# Gold: Price vs Volumn

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(x = metals_data["Gold_Price"], y = metals_data["Gold_Vol."], color = "red", hue = metals_data["Year"] , palette = palette)

plt.title("Gold Price vs. trading Volumes")
plt.xlabel("Price")
plt.ylabel("Volume")
plt.grid()
plt.show()

# %% [markdown]
# We can see how gold prices were very less in 2019, and some part of 2020 (most probably 2020 starting months). Then, it increased for coming years and its trading vol decreased.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Silver: Price vs Volume

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(x = metals_data["Silver_Price"], y = metals_data["Silver_Vol."], color = "red" , hue = metals_data["Year"], palette = palette)

plt.title("Silver Price vs. trading  Volumes")
plt.xlabel("Price")
plt.ylabel("Volumn")
plt.grid()
plt.show()

# %% [markdown]
# Compared to gold, the volume of silver didnt see any major decrease over the years.
#
# Another point to notice is that, its price was lowest and highest at some point in 2020.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Copper: Price vs Volume

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(x = metals_data["Copper_Price"], y = metals_data["Copper_Vol."], color = "red", hue = metals_data["Year"], palette = palette)

plt.title("copper Price vs. trading Volumes")
plt.xlabel("Price")
plt.ylabel("Volumes")
plt.grid()
plt.show()

# %% [markdown]
# Copper volumes were near zero at some points of years from 2019 to 2022.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # Cryptocurrencies:

# %%
Cryptos = ["Bitcoin_Price", "Bitcoin_Vol.", "Ethereum_Price", "Ethereum_Vol."]
Cryptos_data = df[["Date"]+ Cryptos]
Cryptos_data.set_index("Date", inplace = True)

# %%
Cryptos_data.head()
# Out:
#             Bitcoin_Price  Bitcoin_Vol.  Ethereum_Price  Ethereum_Vol.
# Date
# 2024-02-02        43194.7       42650.0         2309.28       246890.0
# 2024-02-01        43081.4       47690.0         2304.28       323610.0
# 2024-01-31        42580.5       56480.0         2283.14       408790.0
# 2024-01-30        42946.2       55130.0         2343.11       387120.0
# 2024-01-29        43299.8       45230.0         2317.79       318840.0

# %% [markdown]
# .

# %% [markdown]
# Crypto: Price trends over time

# %%
plt.figure(figsize = (12,6))
for col in ["Bitcoin_Price", "Ethereum_Price"]:
  plt.plot(Cryptos_data.index, Cryptos_data[col], label = col)

plt.title("Cryptocurrency Price over time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Both Bitcoin and Ethereum price were highest in year 2021 to mid 2022. After this, their prices decreased.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Average Volume trading

# %%
Average_crypto_volumes = Cryptos_data[["Bitcoin_Vol.", "Ethereum_Vol."]].mean()

# %%
Average_crypto_volumes.head()
# Out:
# Bitcoin_Vol.     4.033918e+07
# Ethereum_Vol.    1.801563e+07
# dtype: float64

# %%
plt.figure(figsize = (8,5))
sns.barplot(x = Average_crypto_volumes.index, y = Average_crypto_volumes.values, palette = "viridis")
plt.title("Average Trading Volume of Cryptocurrencies")
plt.xlabel("Cryptocurrencies")
plt.ylabel("Average_Volume")
plt.show()
# Out:
# <ipython-input-61-92c4b7c8886f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = Average_crypto_volumes.index, y = Average_crypto_volumes.values, palette = "viridis")

# %% [markdown]
# Bitcoin volume was more than twice of that of Ethereum. Bitcoin is more popular.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Drawing correlation matrix:

# %%
correlation_data = Cryptos_data[["Bitcoin_Price", "Bitcoin_Vol.", "Ethereum_Price", "Ethereum_Vol."]]
plt.figure(figsize = (8,6))
sns.heatmap(correlation_data.corr(), annot = True, cmap = "coolwarm", fmt = ".2f")
plt.title("Correlation between cryptocurrency price and volumes")
plt.show()

# %% [markdown]
# Obviously there's a very high correlation between Bitcoin and Ethereum Prices.

# %% [markdown]
# .

# %% [markdown]
# .

# %%
Cryptos_data["Year"] = Cryptos_data.index.year
# Out:
# <ipython-input-63-fe216c34d940>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cryptos_data["Year"] = Cryptos_data.index.year

# %% [markdown]
# Bitcoin: Price vs Volume

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(x = Cryptos_data["Bitcoin_Price"], y = Cryptos_data["Bitcoin_Vol."], color = "red", hue = Cryptos_data["Year"], palette = palette)
plt.title("Bitcoin_price vs. trading volumns")
plt.xlabel("Price")
plt.ylabel("Volume")
plt.grid()
plt.show()

# %%
Cryptos_data["Bitcoin_Vol."].describe()
# Out:
# count    1.243000e+03
# mean     4.033918e+07
# std      2.940889e+08
# min      2.600000e+02
# 25%      7.907500e+04
# 50%      2.153100e+05
# 75%      6.151050e+05
# max      4.470000e+09
# Name: Bitcoin_Vol., dtype: float64

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Ethereum: Price vs **Volume**

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(x = Cryptos_data["Ethereum_Price"], y = Cryptos_data["Ethereum_Vol."], color = "red", hue = Cryptos_data["Year"], palette = palette)
plt.title("Ethereum_price vs. trading volums")
plt.xlabel("Price")
plt.ylabel("Volums")
plt.grid()
plt.show()

# %% [markdown]
# It seems that both Bitcoin and Ethereum were mainly traded in 2022.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # **Companies:**

# %%
df.columns
# Out:
# Index(['Date', 'Natural_Gas_Price', 'Natural_Gas_Vol.', 'Crude_oil_Price',
#        'Crude_oil_Vol.', 'Copper_Price', 'Copper_Vol.', 'Bitcoin_Price',
#        'Bitcoin_Vol.', 'Ethereum_Price', 'Ethereum_Vol.', 'S&P_500_Price',
#        'Nasdaq_100_Price', 'Nasdaq_100_Vol.', 'Apple_Price', 'Apple_Vol.',
#        'Tesla_Price', 'Tesla_Vol.', 'Microsoft_Price', 'Microsoft_Vol.',
#        'Silver_Price', 'Silver_Vol.', 'Google_Price', 'Google_Vol.',
#        'Nvidia_Price', 'Nvidia_Vol.', 'Berkshire_Price', 'Berkshire_Vol.',
#        'Netflix_Price', 'Netflix_Vol.', 'Amazon_Price', 'Amazon_Vol.',
#        'Meta_Price', 'Meta_Vol.', 'Gold_Price', 'Gold_Vol.'],
#       dtype='object')

# %%
tech_companies = ["Apple_Price", "Apple_Vol.", "Tesla_Price", "Tesla_Vol.", "Microsoft_Price", "Microsoft_Vol.",
                  "Google_Price", "Google_Vol.", "Nvidia_Price", "Nvidia_Vol.", "Berkshire_Price", "Berkshire_Vol.",
                  "Netflix_Price", "Netflix_Vol.", "Amazon_Price", "Amazon_Vol.", "Meta_Price", "Meta_Vol."]

tech_data = df[["Date"]+ tech_companies]
tech_data.set_index("Date", inplace = True)
tech_data.head()
# Out:
#             Apple_Price   Apple_Vol.  Tesla_Price   Tesla_Vol.  \
# Date
# 2024-02-02       185.85  102550000.0       187.91  110610000.0
# 2024-02-01       186.86   53490000.0       188.86   90680000.0
# 2024-01-31       184.40   54830000.0       187.29  102270000.0
# 2024-01-30       188.04   55270000.0       191.59  105540000.0
# 2024-01-29       191.73   46890000.0       190.93  123600000.0
#
#             Microsoft_Price  Microsoft_Vol.  Google_Price  Google_Vol.  \
# Date
# 2024-02-02           411.22      28260000.0        142.38   62500000.0
# 2024-02-01           403.78      29230000.0        141.16   37120000.0
# 2024-01-31           397.58      46780000.0        140.10   71370000.0
# 2024-01-30           408.59      29340000.0        151.46   33060000.0
# 2024-01-29           409.72      23290000.0        153.51   27590000.0
#
#             Nvidia_Price  Nvidia_Vol.  Berkshire_Price  Berkshire_Vol.  \
# Date
# ...

# %%
tech_data.describe()
# Out:
#        Apple_Price    Apple_Vol.  Tesla_Price    Tesla_Vol.  Microsoft_Price  \
# count  1243.000000  1.243000e+03  1243.000000  1.243000e+03      1243.000000
# mean    125.566533  9.981845e+07   173.590442  1.341790e+08       241.240072
# std      46.114122  5.208192e+07   106.688094  8.509129e+07        73.429838
# min      42.360000  2.404000e+07    11.930000  2.940000e+07       105.250000
# 25%      79.505000  6.599000e+07    53.335000  8.136000e+07       182.525000
# 50%     136.760000  8.749000e+07   202.070000  1.095200e+08       245.380000
# 75%     162.915000  1.170750e+08   251.470000  1.578300e+08       297.120000
# max     198.110000  4.268800e+08   409.970000  9.140800e+08       411.220000
#
#        Microsoft_Vol.  Google_Price   Google_Vol.  Nvidia_Price   Nvidia_Vol.  \
# count    1.243000e+03   1243.000000  1.243000e+03   1243.000000  1.243000e+03
# mean     2.920801e+07     99.670829  3.351599e+07    187.285841  4.560298e+07
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# FAANG Companies Price trend over time:

# %%
plt.figure(figsize = (12,6))
for col in ['Meta_Price', 'Apple_Price', 'Amazon_Price', 'Netflix_Price', 'Google_Price']:
  plt.plot(tech_data.index,tech_data[col], label = col)

plt.title("FAANG companies price over time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %%
selected_companies = ['Apple_Price', 'Tesla_Price', 'Microsoft_Price', 'Google_Price', 'Nvidia_Price',
                      'Meta_Price', 'Netflix_Price', 'Amazon_Price', 'Berkshire_Price']

selected_volumns = [col.replace("Price", "Vol.") for col in selected_companies]
tech_data = df[["Date"]+ selected_companies + selected_volumns]
tech_data.head()
# Out:
#         Date  Apple_Price  Tesla_Price  Microsoft_Price  Google_Price  \
# 0 2024-02-02       185.85       187.91           411.22        142.38
# 1 2024-02-01       186.86       188.86           403.78        141.16
# 2 2024-01-31       184.40       187.29           397.58        140.10
# 3 2024-01-30       188.04       191.59           408.59        151.46
# 4 2024-01-29       191.73       190.93           409.72        153.51
#
#    Nvidia_Price  Meta_Price  Netflix_Price  Amazon_Price  Berkshire_Price  \
# 0        661.60      474.99         564.64        171.81         589498.0
# 1        630.27      394.78         567.51        159.28         581600.0
# 2        615.27      390.14         564.11        155.20         578020.0
# 3        627.74      400.06         562.85        159.00         584680.0
# 4        624.65      401.02         575.79        161.26         578800.0
#
#     Apple_Vol.   Tesla_Vol.  Microsoft_Vol.  Google_Vol.  Nvidia_Vol.  \
# ...

# %%
tech_data[selected_companies].describe()
# Out:
#        Apple_Price  Tesla_Price  Microsoft_Price  Google_Price  Nvidia_Price  \
# count  1243.000000  1243.000000      1243.000000   1243.000000   1243.000000
# mean    125.566533   173.590442       241.240072     99.670829    187.285841
# std      46.114122   106.688094        73.429838     29.766893    134.679941
# min      42.360000    11.930000       105.250000     51.940000     33.450000
# 25%      79.505000    53.335000       182.525000     71.185000     73.905000
# 50%     136.760000   202.070000       245.380000    101.240000    151.590000
# 75%     162.915000   251.470000       297.120000    127.205000    242.140000
# max     198.110000   409.970000       411.220000    153.510000    661.600000
#
#         Meta_Price  Netflix_Price  Amazon_Price  Berkshire_Price
# count  1243.000000    1243.000000   1243.000000      1243.000000
# mean    239.728134     404.839541    128.683234    404273.051488
# std      71.015427     114.989473     30.808631     86369.903899
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Calculating average prices and volumes

# %%
Average_com_Price = tech_data[selected_companies].mean()
Average_com_Volumes = tech_data[selected_volumns].mean()

# Combined bar plot for average prices and volumes
fig, axl = plt.subplots(figsize = (12,6))

# Bar plot for average prices
Average_com_Price.plot(kind = "bar", color = "skyblue", ax = axl, position=0, width=0.4, label='Average Price')
axl.set_ylabel("Average_Price", color = "blue")
axl.tick_params(axis = "y", labelcolor = "blue")


# Bar plot for average volumes (on secondary y-axis)
ax2 = axl.twinx()
Average_com_Volumes.plot(kind = "bar", color = "orange", ax = ax2, position = 1, width = 0.4, label = "Average_Volume")
ax2.set_ylabel("Average Volume" ,color = "orange")

plt.title("Comparision of Average Price and Volumes")
plt.xticks(rotation = 45)
fig.tight_layout()
plt.show()

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Drawing correlation matrix:

# %%
Com_price_corr = tech_data[selected_companies].corr()

plt.figure(figsize = (10,6))
sns.heatmap(Com_price_corr, annot = True, cmap = "coolwarm", fmt = ".2f")
plt.title("Correlation between company prices")
plt.show()

# %%
tech_data.head()
# Out:
#         Date  Apple_Price  Tesla_Price  Microsoft_Price  Google_Price  \
# 0 2024-02-02       185.85       187.91           411.22        142.38
# 1 2024-02-01       186.86       188.86           403.78        141.16
# 2 2024-01-31       184.40       187.29           397.58        140.10
# 3 2024-01-30       188.04       191.59           408.59        151.46
# 4 2024-01-29       191.73       190.93           409.72        153.51
#
#    Nvidia_Price  Meta_Price  Netflix_Price  Amazon_Price  Berkshire_Price  \
# 0        661.60      474.99         564.64        171.81         589498.0
# 1        630.27      394.78         567.51        159.28         581600.0
# 2        615.27      390.14         564.11        155.20         578020.0
# 3        627.74      400.06         562.85        159.00         584680.0
# 4        624.65      401.02         575.79        161.26         578800.0
#
#     Apple_Vol.   Tesla_Vol.  Microsoft_Vol.  Google_Vol.  Nvidia_Vol.  \
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Stock Price trends for all companies:

# %%
Company_Price = ['Apple_Price', 'Tesla_Price', 'Microsoft_Price', 'Google_Price', 'Nvidia_Price',
                  'Meta_Price', 'Netflix_Price', 'Amazon_Price', 'Berkshire_Price']


# Create subplots for time-series trends
num_companies = len(Company_Price)
rows = (num_companies + 2) // 3   # Adjust number of rows for subplots
fid, axes = plt.subplots(rows, 3, figsize = (15, rows*4))

# Flatten axes for easy indexing
axes = axes.flatten()

# Plot each company's time-series data
for idx, company in enumerate(Company_Price):
    ax = axes[idx]
    ax.plot(tech_data.index, tech_data[company], label=company.split('_')[0], color='tab:blue')
    ax.set_title(f"{company.split('_')[0]} Price Trend")
    ax.set_xlabel('Date')
    ax.set_ylabel('Price')
    ax.legend()
    ax.grid()

# Hide any extra subplots (if rows * cols > num_companies)
for i in range(num_companies, len(axes)):
    axes[i].set_visible(False)

# Adjust layout
plt.tight_layout()
plt.suptitle("Time-Series Trends for Tech Companies", fontsize=16, y=1.02)
plt.show()

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # **Index**

# %%
df.head()
# Out:
#         Date  Natural_Gas_Price  Natural_Gas_Vol.  Crude_oil_Price  \
# 0 2024-02-02              2.079          161340.0            72.28
# 1 2024-02-01              2.050          161340.0            73.82
# 2 2024-01-31              2.100          142860.0            75.85
# 3 2024-01-30              2.077          139750.0            77.82
# 4 2024-01-29              2.490            3590.0            76.78
#
#    Crude_oil_Vol.  Copper_Price  Copper_Vol.  Bitcoin_Price  Bitcoin_Vol.  \
# 0        577940.0        3.8215      38000.0        43194.7       42650.0
# 1        577940.0        3.8535      38000.0        43081.4       47690.0
# 2        344490.0        3.9060      38000.0        42580.5       56480.0
# 3        347240.0        3.9110      38000.0        42946.2       55130.0
# 4        331930.0        3.8790      38000.0        43299.8       45230.0
#
#    Ethereum_Price  ...  Berkshire_Price  Berkshire_Vol.  Netflix_Price  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Natural_Gas_Price', 'Natural_Gas_Vol.', 'Crude_oil_Price',
#        'Crude_oil_Vol.', 'Copper_Price', 'Copper_Vol.', 'Bitcoin_Price',
#        'Bitcoin_Vol.', 'Ethereum_Price', 'Ethereum_Vol.', 'S&P_500_Price',
#        'Nasdaq_100_Price', 'Nasdaq_100_Vol.', 'Apple_Price', 'Apple_Vol.',
#        'Tesla_Price', 'Tesla_Vol.', 'Microsoft_Price', 'Microsoft_Vol.',
#        'Silver_Price', 'Silver_Vol.', 'Google_Price', 'Google_Vol.',
#        'Nvidia_Price', 'Nvidia_Vol.', 'Berkshire_Price', 'Berkshire_Vol.',
#        'Netflix_Price', 'Netflix_Vol.', 'Amazon_Price', 'Amazon_Vol.',
#        'Meta_Price', 'Meta_Vol.', 'Gold_Price', 'Gold_Vol.'],
#       dtype='object')

# %%
# Plot S&P 500 and Nasdaq 100 trends over time
plt.figure(figsize = (12,6))
plt.plot(df["Date"], df["S&P_500_Price"], label = "S&P_500", color = "blue" )
plt.plot(df["Date"], df["Nasdaq_100_Price"], label = "Nasdaq_100", color = "orange")

plt.title("S&P 500 and Nasdaq 100 Price trends over time")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %%
index_corr = df[["S&P_500_Price", "Nasdaq_100_Price"]].corr()

plt.figure(figsize = (8,6))
sns.heatmap(index_corr, annot = True, cmap = "coolwarm", fmt = ".2f")
plt.title("Correlation between S&P 500 and Nasdaq 100")
plt.show()

# %%
# Combine datasets for correlation analysis
combined_data = pd.concat([Commodities_data[['Natural_Gas_Price', 'Crude_oil_Price']], metals_data[["Gold_Price", "Silver_Price", "Copper_Price"]],
Cryptos_data[['Bitcoin_Price', 'Ethereum_Price']], tech_data[selected_companies]], axis = 1)

# %%
combined_data.head()
# Out:
#                      Natural_Gas_Price  Crude_oil_Price  Gold_Price  \
# 2024-02-02 00:00:00              2.079            72.28      2053.7
# 2024-02-01 00:00:00              2.050            73.82      2071.1
# 2024-01-31 00:00:00              2.100            75.85      2067.4
# 2024-01-30 00:00:00              2.077            77.82      2050.9
# 2024-01-29 00:00:00              2.490            76.78      2034.9
#
#                      Silver_Price  Copper_Price  Bitcoin_Price  \
# 2024-02-02 00:00:00        22.796        3.8215        43194.7
# 2024-02-01 00:00:00        23.236        3.8535        43081.4
# 2024-01-31 00:00:00        23.169        3.9060        42580.5
# 2024-01-30 00:00:00        23.225        3.9110        42946.2
# 2024-01-29 00:00:00        23.134        3.8790        43299.8
#
#                      Ethereum_Price  Apple_Price  Tesla_Price  \
# 2024-02-02 00:00:00         2309.28          NaN          NaN
# ...

# %%
combined_data = pd.concat([Commodities_data[['Natural_Gas_Price', 'Crude_oil_Price']], metals_data[["Gold_Price", "Silver_Price", "Copper_Price"]],
Cryptos_data[['Bitcoin_Price', 'Ethereum_Price']], tech_data[selected_companies]], axis = 1)
# Compute correlation matrix
combined_corr = combined_data.corr()

plt.figure(figsize = (12,8))
sns.heatmap(combined_corr, annot = True, cmap = "coolwarm", fmt= ".2f")
plt.title("Correlation matrix")
plt.show()
